# %%
# coding: utf-8
import sys
sys.path.append('../예제')
sys.path.append('../예제/ch06')
from common.optimizer import SGD, Adam
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm

# %%
# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = Adam(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# Downloading ptb.test.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9998.98
# | 에폭 1 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 3137.66
# | 에폭 1 |  반복 41 / 1327 | 시간 13[s] | 퍼플렉서티 1240.38
# | 에폭 1 |  반복 61 / 1327 | 시간 19[s] | 퍼플렉서티 967.07
# | 에폭 1 |  반복 81 / 1327 | 시간 26[s] | 퍼플렉서티 808.84
# | 에폭 1 |  반복 101 / 1327 | 시간 33[s] | 퍼플렉서티 663.06
# | 에폭 1 |  반복 121 / 1327 | 시간 40[s] | 퍼플렉서티 622.77
# | 에폭 1 |  반복 141 / 1327 | 시간 46[s] | 퍼플렉서티 595.45
# | 에폭 1 |  반복 161 / 1327 | 시간 52[s] | 퍼플렉서티 585.69
# | 에폭 1 |  반복 181 / 1327 | 시간 59[s] | 퍼플렉서티 577.31
# | 에폭 1 |  반복 201 / 1327 | 시간 65[s] | 퍼플렉서티 506.60
# | 에폭 1 |  반복 221 / 1327 | 시간 72[s] | 퍼플렉서티 488.87
# | 에폭 1 |  반복 241 / 1327 | 시간 78[s] | 퍼플렉서티 450.71
# | 에폭 1 |  반복 261 / 1327 | 시간 85[s] | 퍼플렉서티 458.39
# | 에폭 1 |  반복 281 / 1327 | 시간 92[s] | 퍼플렉서티 455.70
# | 에폭 1 |  반복 301 / 1327 | 시간 98[s] | 퍼플렉서티 395.79
# | 에폭 1 |  반복 321 / 1327 | 시간 105[s] | 퍼플렉서티 342.55
# | 에폭 1 |  반복 341 / 1327 | 시간 111[s] | 퍼플렉서티 407.16
# | 에폭 1 |  반복 361 / 1327 | 시간 117[s] | 퍼플렉서티 404.88
# | 에폭 1 |  반복 381 / 1327 | 시간 123[s] | 퍼플렉서티 329.31
# | 에폭 1 |  반복 401 / 1327 | 시간 130[s] | 퍼플렉서티 351.32
# | 에폭 1 |  반복 421 / 1327 | 시간 136[s] | 퍼플렉서티 340.50
# | 에폭 1 |  반복 441 / 1327 | 시간 143[s] | 퍼플렉서티 322.29
# | 에폭 1 |  반복 461 / 1327 | 시간 150[s] | 퍼플렉서티 323.06
# | 에폭 1 |  반복 481 / 1327 | 시간 157[s] | 퍼플렉서티 304.78
# | 에폭 1 |  반복 501 / 1327 | 시간 163[s] | 퍼플렉서티 314.77
# | 에폭 1 |  반복 521 / 1327 | 시간 169[s] | 퍼플렉서티 299.51
# | 에폭 1 |  반복 541 / 1327 | 시간 175[s] | 퍼플렉서티 312.70
# | 에폭 1 |  반복 561 / 1327 | 시간 181[s] | 퍼플렉서티 287.67
# | 에폭 1 |  반복 581 / 1327 | 시간 188[s] | 퍼플렉서티 256.04
# | 에폭 1 |  반복 601 / 1327 | 시간 195[s] | 퍼플렉서티 337.07
# | 에폭 1 |  반복 621 / 1327 | 시간 201[s] | 퍼플렉서티 305.89
# | 에폭 1 |  반복 641 / 1327 | 시간 208[s] | 퍼플렉서티 281.04
# | 에폭 1 |  반복 661 / 1327 | 시간 215[s] | 퍼플렉서티 271.84
# | 에폭 1 |  반복 681 / 1327 | 시간 222[s] | 퍼플렉서티 229.47
# | 에폭 1 |  반복 701 / 1327 | 시간 228[s] | 퍼플렉서티 249.94
# | 에폭 1 |  반복 721 / 1327 | 시간 235[s] | 퍼플렉서티 257.59
# | 에폭 1 |  반복 741 / 1327 | 시간 242[s] | 퍼플렉서티 218.72
# | 에폭 1 |  반복 761 / 1327 | 시간 248[s] | 퍼플렉서티 229.70
# | 에폭 1 |  반복 781 / 1327 | 시간 255[s] | 퍼플렉서티 218.42
# | 에폭 1 |  반복 801 / 1327 | 시간 262[s] | 퍼플렉서티 238.76
# | 에폭 1 |  반복 821 / 1327 | 시간 268[s] | 퍼플렉서티 223.68
# | 에폭 1 |  반복 841 / 1327 | 시간 274[s] | 퍼플렉서티 229.52
# | 에폭 1 |  반복 861 / 1327 | 시간 281[s] | 퍼플렉서티 222.28
# | 에폭 1 |  반복 881 / 1327 | 시간 287[s] | 퍼플렉서티 206.87
# | 에폭 1 |  반복 901 / 1327 | 시간 294[s] | 퍼플렉서티 254.26
# | 에폭 1 |  반복 921 / 1327 | 시간 300[s] | 퍼플렉서티 225.61
# | 에폭 1 |  반복 941 / 1327 | 시간 306[s] | 퍼플렉서티 229.24
# | 에폭 1 |  반복 961 / 1327 | 시간 312[s] | 퍼플렉서티 245.64
# | 에폭 1 |  반복 981 / 1327 | 시간 318[s] | 퍼플렉서티 230.45
# | 에폭 1 |  반복 1001 / 1327 | 시간 324[s] | 퍼플렉서티 193.31
# | 에폭 1 |  반복 1021 / 1327 | 시간 330[s] | 퍼플렉서티 225.36
# | 에폭 1 |  반복 1041 / 1327 | 시간 336[s] | 퍼플렉서티 206.43
# | 에폭 1 |  반복 1061 / 1327 | 시간 342[s] | 퍼플렉서티 196.11
# | 에폭 1 |  반복 1081 / 1327 | 시간 348[s] | 퍼플렉서티 168.33
# | 에폭 1 |  반복 1101 / 1327 | 시간 354[s] | 퍼플렉서티 191.62
# | 에폭 1 |  반복 1121 / 1327 | 시간 361[s] | 퍼플렉서티 228.16
# | 에폭 1 |  반복 1141 / 1327 | 시간 367[s] | 퍼플렉서티 207.65
# | 에폭 1 |  반복 1161 / 1327 | 시간 374[s] | 퍼플렉서티 198.92
# | 에폭 1 |  반복 1181 / 1327 | 시간 380[s] | 퍼플렉서티 190.26
# | 에폭 1 |  반복 1201 / 1327 | 시간 387[s] | 퍼플렉서티 161.22
# | 에폭 1 |  반복 1221 / 1327 | 시간 393[s] | 퍼플렉서티 158.97
# | 에폭 1 |  반복 1241 / 1327 | 시간 400[s] | 퍼플렉서티 188.30
# | 에폭 1 |  반복 1261 / 1327 | 시간 406[s] | 퍼플렉서티 170.76
# | 에폭 1 |  반복 1281 / 1327 | 시간 412[s] | 퍼플렉서티 178.34
# | 에폭 1 |  반복 1301 / 1327 | 시간 419[s] | 퍼플렉서티 221.20
# | 에폭 1 |  반복 1321 / 1327 | 시간 425[s] | 퍼플렉서티 208.69
# | 에폭 2 |  반복 1 / 1327 | 시간 427[s] | 퍼플렉서티 223.55
# | 에폭 2 |  반복 21 / 1327 | 시간 433[s] | 퍼플렉서티 203.43
# | 에폭 2 |  반복 41 / 1327 | 시간 439[s] | 퍼플렉서티 189.52
# | 에폭 2 |  반복 61 / 1327 | 시간 445[s] | 퍼플렉서티 176.06
# | 에폭 2 |  반복 81 / 1327 | 시간 452[s] | 퍼플렉서티 159.15
# | 에폭 2 |  반복 101 / 1327 | 시간 459[s] | 퍼플렉서티 152.13
# | 에폭 2 |  반복 121 / 1327 | 시간 466[s] | 퍼플렉서티 159.21
# | 에폭 2 |  반복 141 / 1327 | 시간 474[s] | 퍼플렉서티 178.63
# | 에폭 2 |  반복 161 / 1327 | 시간 481[s] | 퍼플렉서티 192.01
# | 에폭 2 |  반복 181 / 1327 | 시간 488[s] | 퍼플렉서티 200.33
# | 에폭 2 |  반복 201 / 1327 | 시간 495[s] | 퍼플렉서티 184.39
# | 에폭 2 |  반복 221 / 1327 | 시간 501[s] | 퍼플렉서티 184.31
# | 에폭 2 |  반복 241 / 1327 | 시간 507[s] | 퍼플렉서티 176.36
# | 에폭 2 |  반복 261 / 1327 | 시간 514[s] | 퍼플렉서티 184.90
# | 에폭 2 |  반복 281 / 1327 | 시간 520[s] | 퍼플렉서티 185.09
# | 에폭 2 |  반복 301 / 1327 | 시간 527[s] | 퍼플렉서티 167.14
# | 에폭 2 |  반복 321 / 1327 | 시간 535[s] | 퍼플렉서티 138.77
# | 에폭 2 |  반복 341 / 1327 | 시간 542[s] | 퍼플렉서티 172.50
# | 에폭 2 |  반복 361 / 1327 | 시간 549[s] | 퍼플렉서티 197.71
# | 에폭 2 |  반복 381 / 1327 | 시간 555[s] | 퍼플렉서티 153.17
# | 에폭 2 |  반복 401 / 1327 | 시간 562[s] | 퍼플렉서티 166.60
# | 에폭 2 |  반복 421 / 1327 | 시간 568[s] | 퍼플렉서티 154.01
# | 에폭 2 |  반복 441 / 1327 | 시간 574[s] | 퍼플렉서티 162.93
# | 에폭 2 |  반복 461 / 1327 | 시간 581[s] | 퍼플렉서티 156.69
# | 에폭 2 |  반복 481 / 1327 | 시간 588[s] | 퍼플렉서티 156.23
# | 에폭 2 |  반복 501 / 1327 | 시간 594[s] | 퍼플렉서티 171.30
# | 에폭 2 |  반복 521 / 1327 | 시간 601[s] | 퍼플렉서티 171.42
# | 에폭 2 |  반복 541 / 1327 | 시간 608[s] | 퍼플렉서티 173.89
# | 에폭 2 |  반복 561 / 1327 | 시간 615[s] | 퍼플렉서티 156.18
# | 에폭 2 |  반복 581 / 1327 | 시간 623[s] | 퍼플렉서티 138.51
# | 에폭 2 |  반복 601 / 1327 | 시간 630[s] | 퍼플렉서티 189.27
# | 에폭 2 |  반복 621 / 1327 | 시간 637[s] | 퍼플렉서티 181.21
# | 에폭 2 |  반복 641 / 1327 | 시간 643[s] | 퍼플렉서티 164.66
# | 에폭 2 |  반복 661 / 1327 | 시간 650[s] | 퍼플렉서티 155.98
# | 에폭 2 |  반복 681 / 1327 | 시간 656[s] | 퍼플렉서티 130.20
# | 에폭 2 |  반복 701 / 1327 | 시간 663[s] | 퍼플렉서티 150.70
# | 에폭 2 |  반복 721 / 1327 | 시간 669[s] | 퍼플렉서티 159.44
# | 에폭 2 |  반복 741 / 1327 | 시간 676[s] | 퍼플렉서티 133.81
# | 에폭 2 |  반복 761 / 1327 | 시간 683[s] | 퍼플렉서티 131.00
# | 에폭 2 |  반복 781 / 1327 | 시간 689[s] | 퍼플렉서티 135.72
# | 에폭 2 |  반복 801 / 1327 | 시간 696[s] | 퍼플렉서티 147.28
# | 에폭 2 |  반복 821 / 1327 | 시간 702[s] | 퍼플렉서티 143.51
# | 에폭 2 |  반복 841 / 1327 | 시간 709[s] | 퍼플렉서티 143.53
# | 에폭 2 |  반복 861 / 1327 | 시간 715[s] | 퍼플렉서티 145.62
# | 에폭 2 |  반복 881 / 1327 | 시간 722[s] | 퍼플렉서티 130.06
# | 에폭 2 |  반복 901 / 1327 | 시간 729[s] | 퍼플렉서티 166.94
# | 에폭 2 |  반복 921 / 1327 | 시간 735[s] | 퍼플렉서티 146.37
# | 에폭 2 |  반복 941 / 1327 | 시간 741[s] | 퍼플렉서티 153.68
# | 에폭 2 |  반복 961 / 1327 | 시간 747[s] | 퍼플렉서티 164.65
# | 에폭 2 |  반복 981 / 1327 | 시간 753[s] | 퍼플렉서티 154.33
# | 에폭 2 |  반복 1001 / 1327 | 시간 760[s] | 퍼플렉서티 130.55
# | 에폭 2 |  반복 1021 / 1327 | 시간 766[s] | 퍼플렉서티 155.29
# | 에폭 2 |  반복 1041 / 1327 | 시간 772[s] | 퍼플렉서티 143.14
# | 에폭 2 |  반복 1061 / 1327 | 시간 778[s] | 퍼플렉서티 128.63
# | 에폭 2 |  반복 1081 / 1327 | 시간 784[s] | 퍼플렉서티 111.04
# | 에폭 2 |  반복 1101 / 1327 | 시간 791[s] | 퍼플렉서티 121.18
# | 에폭 2 |  반복 1121 / 1327 | 시간 798[s] | 퍼플렉서티 153.99
# | 에폭 2 |  반복 1141 / 1327 | 시간 805[s] | 퍼플렉서티 141.32
# | 에폭 2 |  반복 1161 / 1327 | 시간 812[s] | 퍼플렉서티 132.54
# | 에폭 2 |  반복 1181 / 1327 | 시간 818[s] | 퍼플렉서티 134.43
# | 에폭 2 |  반복 1201 / 1327 | 시간 824[s] | 퍼플렉서티 111.54
# | 에폭 2 |  반복 1221 / 1327 | 시간 831[s] | 퍼플렉서티 109.23
# | 에폭 2 |  반복 1241 / 1327 | 시간 838[s] | 퍼플렉서티 130.04
# | 에폭 2 |  반복 1261 / 1327 | 시간 845[s] | 퍼플렉서티 123.43
# | 에폭 2 |  반복 1281 / 1327 | 시간 852[s] | 퍼플렉서티 121.67
# | 에폭 2 |  반복 1301 / 1327 | 시간 859[s] | 퍼플렉서티 156.86
# | 에폭 2 |  반복 1321 / 1327 | 시간 867[s] | 퍼플렉서티 152.79
# | 에폭 3 |  반복 1 / 1327 | 시간 870[s] | 퍼플렉서티 159.07
# | 에폭 3 |  반복 21 / 1327 | 시간 877[s] | 퍼플렉서티 143.11
# | 에폭 3 |  반복 41 / 1327 | 시간 885[s] | 퍼플렉서티 135.59
# | 에폭 3 |  반복 61 / 1327 | 시간 892[s] | 퍼플렉서티 126.88
# | 에폭 3 |  반복 81 / 1327 | 시간 900[s] | 퍼플렉서티 116.35
# | 에폭 3 |  반복 101 / 1327 | 시간 907[s] | 퍼플렉서티 105.20
# | 에폭 3 |  반복 121 / 1327 | 시간 914[s] | 퍼플렉서티 116.18
# | 에폭 3 |  반복 141 / 1327 | 시간 922[s] | 퍼플렉서티 126.60
# | 에폭 3 |  반복 161 / 1327 | 시간 929[s] | 퍼플렉서티 141.34
# | 에폭 3 |  반복 181 / 1327 | 시간 936[s] | 퍼플렉서티 150.87
# | 에폭 3 |  반복 201 / 1327 | 시간 943[s] | 퍼플렉서티 141.33
# | 에폭 3 |  반복 221 / 1327 | 시간 950[s] | 퍼플렉서티 141.31
# | 에폭 3 |  반복 241 / 1327 | 시간 956[s] | 퍼플렉서티 134.85
# | 에폭 3 |  반복 261 / 1327 | 시간 963[s] | 퍼플렉서티 138.67
# | 에폭 3 |  반복 281 / 1327 | 시간 970[s] | 퍼플렉서티 141.21
# | 에폭 3 |  반복 301 / 1327 | 시간 977[s] | 퍼플렉서티 124.81
# | 에폭 3 |  반복 321 / 1327 | 시간 983[s] | 퍼플렉서티 102.18
# | 에폭 3 |  반복 341 / 1327 | 시간 990[s] | 퍼플렉서티 123.57
# | 에폭 3 |  반복 361 / 1327 | 시간 997[s] | 퍼플렉서티 151.39
# | 에폭 3 |  반복 381 / 1327 | 시간 1003[s] | 퍼플렉서티 114.19
# | 에폭 3 |  반복 401 / 1327 | 시간 1010[s] | 퍼플렉서티 128.92
# | 에폭 3 |  반복 421 / 1327 | 시간 1016[s] | 퍼플렉서티 113.09
# | 에폭 3 |  반복 441 / 1327 | 시간 1022[s] | 퍼플렉서티 123.67
# | 에폭 3 |  반복 461 / 1327 | 시간 1028[s] | 퍼플렉서티 118.71
# | 에폭 3 |  반복 481 / 1327 | 시간 1035[s] | 퍼플렉서티 119.89
# | 에폭 3 |  반복 501 / 1327 | 시간 1041[s] | 퍼플렉서티 128.93
# | 에폭 3 |  반복 521 / 1327 | 시간 1047[s] | 퍼플렉서티 136.16
# | 에폭 3 |  반복 541 / 1327 | 시간 1053[s] | 퍼플렉서티 136.57
# | 에폭 3 |  반복 561 / 1327 | 시간 1060[s] | 퍼플렉서티 119.37
# | 에폭 3 |  반복 581 / 1327 | 시간 1067[s] | 퍼플렉서티 104.63
# | 에폭 3 |  반복 601 / 1327 | 시간 1073[s] | 퍼플렉서티 148.34
# | 에폭 3 |  반복 621 / 1327 | 시간 1080[s] | 퍼플렉서티 142.08
# | 에폭 3 |  반복 641 / 1327 | 시간 1087[s] | 퍼플렉서티 130.14
# | 에폭 3 |  반복 661 / 1327 | 시간 1095[s] | 퍼플렉서티 121.57
# | 에폭 3 |  반복 681 / 1327 | 시간 1101[s] | 퍼플렉서티 100.73
# | 에폭 3 |  반복 701 / 1327 | 시간 1107[s] | 퍼플렉서티 118.89
# | 에폭 3 |  반복 721 / 1327 | 시간 1114[s] | 퍼플렉서티 125.96
# | 에폭 3 |  반복 741 / 1327 | 시간 1121[s] | 퍼플렉서티 107.22
# | 에폭 3 |  반복 761 / 1327 | 시간 1127[s] | 퍼플렉서티 104.09
# | 에폭 3 |  반복 781 / 1327 | 시간 1133[s] | 퍼플렉서티 106.85
# | 에폭 3 |  반복 801 / 1327 | 시간 1140[s] | 퍼플렉서티 115.99
# | 에폭 3 |  반복 821 / 1327 | 시간 1147[s] | 퍼플렉서티 115.82
# | 에폭 3 |  반복 841 / 1327 | 시간 1154[s] | 퍼플렉서티 114.17
# | 에폭 3 |  반복 861 / 1327 | 시간 1160[s] | 퍼플렉서티 120.02
# | 에폭 3 |  반복 881 / 1327 | 시간 1167[s] | 퍼플렉서티 105.60
# | 에폭 3 |  반복 901 / 1327 | 시간 1173[s] | 퍼플렉서티 132.29
# | 에폭 3 |  반복 921 / 1327 | 시간 1180[s] | 퍼플렉서티 118.96
# | 에폭 3 |  반복 941 / 1327 | 시간 1187[s] | 퍼플렉서티 127.90
# | 에폭 3 |  반복 961 / 1327 | 시간 1193[s] | 퍼플렉서티 131.23
# | 에폭 3 |  반복 981 / 1327 | 시간 1200[s] | 퍼플렉서티 124.43
# | 에폭 3 |  반복 1001 / 1327 | 시간 1206[s] | 퍼플렉서티 109.01
# | 에폭 3 |  반복 1021 / 1327 | 시간 1213[s] | 퍼플렉서티 127.42
# | 에폭 3 |  반복 1041 / 1327 | 시간 1219[s] | 퍼플렉서티 118.95
# | 에폭 3 |  반복 1061 / 1327 | 시간 1225[s] | 퍼플렉서티 102.85
# | 에폭 3 |  반복 1081 / 1327 | 시간 1232[s] | 퍼플렉서티 89.38
# | 에폭 3 |  반복 1101 / 1327 | 시간 1239[s] | 퍼플렉서티 96.04
# | 에폭 3 |  반복 1121 / 1327 | 시간 1246[s] | 퍼플렉서티 122.67
# | 에폭 3 |  반복 1141 / 1327 | 시간 1252[s] | 퍼플렉서티 114.65
# | 에폭 3 |  반복 1161 / 1327 | 시간 1259[s] | 퍼플렉서티 105.20
# | 에폭 3 |  반복 1181 / 1327 | 시간 1266[s] | 퍼플렉서티 110.48
# | 에폭 3 |  반복 1201 / 1327 | 시간 1272[s] | 퍼플렉서티 93.47
# | 에폭 3 |  반복 1221 / 1327 | 시간 1279[s] | 퍼플렉서티 88.16
# | 에폭 3 |  반복 1241 / 1327 | 시간 1286[s] | 퍼플렉서티 105.18
# | 에폭 3 |  반복 1261 / 1327 | 시간 1292[s] | 퍼플렉서티 104.82
# | 에폭 3 |  반복 1281 / 1327 | 시간 1299[s] | 퍼플렉서티 99.66
# | 에폭 3 |  반복 1301 / 1327 | 시간 1305[s] | 퍼플렉서티 128.38
# | 에폭 3 |  반복 1321 / 1327 | 시간 1312[s] | 퍼플렉서티 125.40
# | 에폭 4 |  반복 1 / 1327 | 시간 1314[s] | 퍼플렉서티 132.06
# | 에폭 4 |  반복 21 / 1327 | 시간 1320[s] | 퍼플렉서티 119.98
# | 에폭 4 |  반복 41 / 1327 | 시간 1327[s] | 퍼플렉서티 105.31
# | 에폭 4 |  반복 61 / 1327 | 시간 1333[s] | 퍼플렉서티 107.38
# | 에폭 4 |  반복 81 / 1327 | 시간 1340[s] | 퍼플렉서티 95.62
# | 에폭 4 |  반복 101 / 1327 | 시간 1347[s] | 퍼플렉서티 85.99
# | 에폭 4 |  반복 121 / 1327 | 시간 1353[s] | 퍼플렉서티 95.49
# | 에폭 4 |  반복 141 / 1327 | 시간 1360[s] | 퍼플렉서티 104.02
# | 에폭 4 |  반복 161 / 1327 | 시간 1366[s] | 퍼플렉서티 116.86
# | 에폭 4 |  반복 181 / 1327 | 시간 1373[s] | 퍼플렉서티 128.53
# | 에폭 4 |  반복 201 / 1327 | 시간 1379[s] | 퍼플렉서티 119.83
# | 에폭 4 |  반복 221 / 1327 | 시간 1386[s] | 퍼플렉서티 121.53
# | 에폭 4 |  반복 241 / 1327 | 시간 1393[s] | 퍼플렉서티 115.78
# | 에폭 4 |  반복 261 / 1327 | 시간 1400[s] | 퍼플렉서티 113.86
# | 에폭 4 |  반복 281 / 1327 | 시간 1406[s] | 퍼플렉서티 120.21
# | 에폭 4 |  반복 301 / 1327 | 시간 1412[s] | 퍼플렉서티 104.11
# | 에폭 4 |  반복 321 / 1327 | 시간 1418[s] | 퍼플렉서티 84.76
# | 에폭 4 |  반복 341 / 1327 | 시간 1424[s] | 퍼플렉서티 99.65
# | 에폭 4 |  반복 361 / 1327 | 시간 1430[s] | 퍼플렉서티 126.48
# | 에폭 4 |  반복 381 / 1327 | 시간 1436[s] | 퍼플렉서티 96.56
# | 에폭 4 |  반복 401 / 1327 | 시간 1442[s] | 퍼플렉서티 110.81
# | 에폭 4 |  반복 421 / 1327 | 시간 1448[s] | 퍼플렉서티 92.56
# | 에폭 4 |  반복 441 / 1327 | 시간 1454[s] | 퍼플렉서티 102.72
# | 에폭 4 |  반복 461 / 1327 | 시간 1460[s] | 퍼플렉서티 99.88
# | 에폭 4 |  반복 481 / 1327 | 시간 1466[s] | 퍼플렉서티 102.99
# | 에폭 4 |  반복 501 / 1327 | 시간 1472[s] | 퍼플렉서티 107.75
# | 에폭 4 |  반복 521 / 1327 | 시간 1478[s] | 퍼플렉서티 114.79
# | 에폭 4 |  반복 541 / 1327 | 시간 1484[s] | 퍼플렉서티 112.72
# | 에폭 4 |  반복 561 / 1327 | 시간 1491[s] | 퍼플렉서티 103.16
# | 에폭 4 |  반복 581 / 1327 | 시간 1497[s] | 퍼플렉서티 88.89
# | 에폭 4 |  반복 601 / 1327 | 시간 1504[s] | 퍼플렉서티 125.40
# | 에폭 4 |  반복 621 / 1327 | 시간 1510[s] | 퍼플렉서티 121.05
# | 에폭 4 |  반복 641 / 1327 | 시간 1518[s] | 퍼플렉서티 111.38
# | 에폭 4 |  반복 661 / 1327 | 시간 1524[s] | 퍼플렉서티 103.65
# | 에폭 4 |  반복 681 / 1327 | 시간 1531[s] | 퍼플렉서티 84.76
# | 에폭 4 |  반복 701 / 1327 | 시간 1538[s] | 퍼플렉서티 102.22
# | 에폭 4 |  반복 721 / 1327 | 시간 1546[s] | 퍼플렉서티 106.84
# | 에폭 4 |  반복 741 / 1327 | 시간 1553[s] | 퍼플렉서티 95.46
# | 에폭 4 |  반복 761 / 1327 | 시간 1559[s] | 퍼플렉서티 89.64
# | 에폭 4 |  반복 781 / 1327 | 시간 1566[s] | 퍼플렉서티 90.04
# | 에폭 4 |  반복 801 / 1327 | 시간 1572[s] | 퍼플렉서티 99.02
# | 에폭 4 |  반복 821 / 1327 | 시간 1579[s] | 퍼플렉서티 102.71
# | 에폭 4 |  반복 841 / 1327 | 시간 1586[s] | 퍼플렉서티 98.00
# | 에폭 4 |  반복 861 / 1327 | 시간 1592[s] | 퍼플렉서티 103.58
# | 에폭 4 |  반복 881 / 1327 | 시간 1599[s] | 퍼플렉서티 91.22
# | 에폭 4 |  반복 901 / 1327 | 시간 1606[s] | 퍼플렉서티 115.53
# | 에폭 4 |  반복 921 / 1327 | 시간 1612[s] | 퍼플렉서티 103.46
# | 에폭 4 |  반복 941 / 1327 | 시간 1619[s] | 퍼플렉서티 112.07
# | 에폭 4 |  반복 961 / 1327 | 시간 1626[s] | 퍼플렉서티 111.57
# | 에폭 4 |  반복 981 / 1327 | 시간 1633[s] | 퍼플렉서티 107.11
# | 에폭 4 |  반복 1001 / 1327 | 시간 1640[s] | 퍼플렉서티 97.12
# | 에폭 4 |  반복 1021 / 1327 | 시간 1646[s] | 퍼플렉서티 111.89
# | 에폭 4 |  반복 1041 / 1327 | 시간 1652[s] | 퍼플렉서티 103.45
# | 에폭 4 |  반복 1061 / 1327 | 시간 1658[s] | 퍼플렉서티 89.20
# | 에폭 4 |  반복 1081 / 1327 | 시간 1664[s] | 퍼플렉서티 79.07
# | 에폭 4 |  반복 1101 / 1327 | 시간 1670[s] | 퍼플렉서티 79.55
# | 에폭 4 |  반복 1121 / 1327 | 시간 1676[s] | 퍼플렉서티 102.84
# | 에폭 4 |  반복 1141 / 1327 | 시간 1682[s] | 퍼플렉서티 100.24
# | 에폭 4 |  반복 1161 / 1327 | 시간 1689[s] | 퍼플렉서티 90.89
# | 에폭 4 |  반복 1181 / 1327 | 시간 1695[s] | 퍼플렉서티 94.58
# | 에폭 4 |  반복 1201 / 1327 | 시간 1701[s] | 퍼플렉서티 82.99
# | 에폭 4 |  반복 1221 / 1327 | 시간 1706[s] | 퍼플렉서티 75.42
# | 에폭 4 |  반복 1241 / 1327 | 시간 1713[s] | 퍼플렉서티 90.89
# | 에폭 4 |  반복 1261 / 1327 | 시간 1719[s] | 퍼플렉서티 93.31
# | 에폭 4 |  반복 1281 / 1327 | 시간 1725[s] | 퍼플렉서티 88.81
# | 에폭 4 |  반복 1301 / 1327 | 시간 1731[s] | 퍼플렉서티 110.22
# | 에폭 4 |  반복 1321 / 1327 | 시간 1737[s] | 퍼플렉서티 108.87
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  133.54770988836316

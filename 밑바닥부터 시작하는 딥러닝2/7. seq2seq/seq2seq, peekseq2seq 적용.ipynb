# %%
# coding: utf-8
import sys
sys.path.append('../예제/ch07')
sys.path.append('../예제')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

# %%
# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = False  # True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# %%
# 일반 혹은 엿보기(Peeky) 설정 =====================================
#model = Seq2seq(vocab_size, wordvec_size, hidden_size)
model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.57
# | 에폭 1 |  반복 21 / 351 | 시간 1[s] | 손실 2.49
# | 에폭 1 |  반복 41 / 351 | 시간 2[s] | 손실 2.20
# | 에폭 1 |  반복 61 / 351 | 시간 3[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 4[s] | 손실 1.84
# | 에폭 1 |  반복 101 / 351 | 시간 5[s] | 손실 1.80
# | 에폭 1 |  반복 121 / 351 | 시간 7[s] | 손실 1.79
# | 에폭 1 |  반복 141 / 351 | 시간 8[s] | 손실 1.77
# | 에폭 1 |  반복 161 / 351 | 시간 9[s] | 손실 1.77
# | 에폭 1 |  반복 181 / 351 | 시간 10[s] | 손실 1.76
# | 에폭 1 |  반복 201 / 351 | 시간 11[s] | 손실 1.76
# | 에폭 1 |  반복 221 / 351 | 시간 12[s] | 손실 1.75
# | 에폭 1 |  반복 241 / 351 | 시간 14[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 15[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 16[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 17[s] | 손실 1.73
# | 에폭 1 |  반복 321 / 351 | 시간 18[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 19[s] | 손실 1.73
# Q 77+85
# T 162
# X 107
# ---
# Q 975+164
# T 1139
# X 1011
# ---
# Q 582+84
# T 666
# X 103
# ---
# Q 8+155
# T 163
# X 101
# ---
# Q 367+55
# T 422
# X 103
# ---
# Q 600+257
# T 857
# X 1023
# ---
# Q 761+292
# T 1053
# X 1023
# ---
# Q 830+597
# T 1427
# X 1011
# ---
# Q 26+838
# T 864
# X 103
# ---
# Q 143+93
# T 236
# X 323
# ---
# 검증 정확도 0.180%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 21 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 41 / 351 | 시간 2[s] | 손실 1.71
# | 에폭 2 |  반복 61 / 351 | 시간 3[s] | 손실 1.70
# | 에폭 2 |  반복 81 / 351 | 시간 4[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 5[s] | 손실 1.70
# | 에폭 2 |  반복 121 / 351 | 시간 6[s] | 손실 1.71
# | 에폭 2 |  반복 141 / 351 | 시간 7[s] | 손실 1.70
# | 에폭 2 |  반복 161 / 351 | 시간 9[s] | 손실 1.69
# | 에폭 2 |  반복 181 / 351 | 시간 10[s] | 손실 1.69
# | 에폭 2 |  반복 201 / 351 | 시간 11[s] | 손실 1.68
# | 에폭 2 |  반복 221 / 351 | 시간 12[s] | 손실 1.68
# | 에폭 2 |  반복 241 / 351 | 시간 13[s] | 손실 1.69
# | 에폭 2 |  반복 261 / 351 | 시간 14[s] | 손실 1.68
# | 에폭 2 |  반복 281 / 351 | 시간 15[s] | 손실 1.68
# | 에폭 2 |  반복 301 / 351 | 시간 16[s] | 손실 1.66
# | 에폭 2 |  반복 321 / 351 | 시간 17[s] | 손실 1.66
# | 에폭 2 |  반복 341 / 351 | 시간 19[s] | 손실 1.65
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 700
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 400
# ---
# Q 600+257
# T 857
# X 1009
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1240
# ---
# Q 26+838
# T 864
# X 400
# ---
# Q 143+93
# T 236
# X 280
# ---
# 검증 정확도 0.220%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.65
# | 에폭 3 |  반복 21 / 351 | 시간 1[s] | 손실 1.64
# | 에폭 3 |  반복 41 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 61 / 351 | 시간 3[s] | 손실 1.60
# | 에폭 3 |  반복 81 / 351 | 시간 4[s] | 손실 1.58
# | 에폭 3 |  반복 101 / 351 | 시간 5[s] | 손실 1.56
# | 에폭 3 |  반복 121 / 351 | 시간 6[s] | 손실 1.54
# | 에폭 3 |  반복 141 / 351 | 시간 8[s] | 손실 1.53
# | 에폭 3 |  반복 161 / 351 | 시간 9[s] | 손실 1.52
# | 에폭 3 |  반복 181 / 351 | 시간 10[s] | 손실 1.49
# | 에폭 3 |  반복 201 / 351 | 시간 11[s] | 손실 1.48
# | 에폭 3 |  반복 221 / 351 | 시간 12[s] | 손실 1.45
# | 에폭 3 |  반복 241 / 351 | 시간 13[s] | 손실 1.43
# | 에폭 3 |  반복 261 / 351 | 시간 14[s] | 손실 1.42
# | 에폭 3 |  반복 281 / 351 | 시간 16[s] | 손실 1.40
# | 에폭 3 |  반복 301 / 351 | 시간 17[s] | 손실 1.38
# | 에폭 3 |  반복 321 / 351 | 시간 18[s] | 손실 1.36
# | 에폭 3 |  반복 341 / 351 | 시간 19[s] | 손실 1.35
# Q 77+85
# T 162
# X 152
# ---
# Q 975+164
# T 1139
# X 1194
# ---
# Q 582+84
# T 666
# X 744
# ---
# Q 8+155
# T 163
# X 151
# ---
# Q 367+55
# T 422
# X 441
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# X 1006
# ---
# Q 830+597
# T 1427
# X 1444
# ---
# Q 26+838
# T 864
# X 814
# ---
# Q 143+93
# T 236
# X 291
# ---
# 검증 정확도 1.400%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.33
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.33
# | 에폭 4 |  반복 41 / 351 | 시간 2[s] | 손실 1.31
# | 에폭 4 |  반복 61 / 351 | 시간 3[s] | 손실 1.31
# | 에폭 4 |  반복 81 / 351 | 시간 4[s] | 손실 1.29
# | 에폭 4 |  반복 101 / 351 | 시간 5[s] | 손실 1.29
# | 에폭 4 |  반복 121 / 351 | 시간 6[s] | 손실 1.27
# | 에폭 4 |  반복 141 / 351 | 시간 8[s] | 손실 1.26
# | 에폭 4 |  반복 161 / 351 | 시간 9[s] | 손실 1.25
# | 에폭 4 |  반복 181 / 351 | 시간 10[s] | 손실 1.24
# | 에폭 4 |  반복 201 / 351 | 시간 11[s] | 손실 1.23
# | 에폭 4 |  반복 221 / 351 | 시간 12[s] | 손실 1.22
# | 에폭 4 |  반복 241 / 351 | 시간 13[s] | 손실 1.21
# | 에폭 4 |  반복 261 / 351 | 시간 15[s] | 손실 1.21
# | 에폭 4 |  반복 281 / 351 | 시간 16[s] | 손실 1.20
# | 에폭 4 |  반복 301 / 351 | 시간 17[s] | 손실 1.17
# | 에폭 4 |  반복 321 / 351 | 시간 18[s] | 손실 1.17
# | 에폭 4 |  반복 341 / 351 | 시간 19[s] | 손실 1.16
# Q 77+85
# T 162
# X 168
# ---
# Q 975+164
# T 1139
# X 1180
# ---
# Q 582+84
# T 666
# X 633
# ---
# Q 8+155
# T 163
# X 153
# ---
# Q 367+55
# T 422
# X 403
# ---
# Q 600+257
# T 857
# X 853
# ---
# Q 761+292
# T 1053
# X 1027
# ---
# Q 830+597
# T 1427
# X 1483
# ---
# Q 26+838
# T 864
# X 888
# ---
# Q 143+93
# T 236
# X 283
# ---
# 검증 정확도 3.000%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.14
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 1.14
# | 에폭 5 |  반복 41 / 351 | 시간 2[s] | 손실 1.14
# | 에폭 5 |  반복 61 / 351 | 시간 3[s] | 손실 1.13
# | 에폭 5 |  반복 81 / 351 | 시간 4[s] | 손실 1.11
# | 에폭 5 |  반복 101 / 351 | 시간 5[s] | 손실 1.10
# | 에폭 5 |  반복 121 / 351 | 시간 6[s] | 손실 1.09
# | 에폭 5 |  반복 141 / 351 | 시간 8[s] | 손실 1.09
# | 에폭 5 |  반복 161 / 351 | 시간 9[s] | 손실 1.08
# | 에폭 5 |  반복 181 / 351 | 시간 10[s] | 손실 1.06
# | 에폭 5 |  반복 201 / 351 | 시간 11[s] | 손실 1.05
# | 에폭 5 |  반복 221 / 351 | 시간 12[s] | 손실 1.05
# | 에폭 5 |  반복 241 / 351 | 시간 14[s] | 손실 1.04
# | 에폭 5 |  반복 261 / 351 | 시간 15[s] | 손실 1.04
# | 에폭 5 |  반복 281 / 351 | 시간 16[s] | 손실 1.03
# | 에폭 5 |  반복 301 / 351 | 시간 17[s] | 손실 1.01
# | 에폭 5 |  반복 321 / 351 | 시간 18[s] | 손실 1.01
# | 에폭 5 |  반복 341 / 351 | 시간 19[s] | 손실 1.00
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1128
# ---
# Q 582+84
# T 666
# X 650
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 404
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1025
# ---
# Q 830+597
# T 1427
# X 1400
# ---
# Q 26+838
# T 864
# X 870
# ---
# Q 143+93
# T 236
# X 209
# ---
# 검증 정확도 4.920%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 6 |  반복 21 / 351 | 시간 1[s] | 손실 0.98
# | 에폭 6 |  반복 41 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 6 |  반복 61 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 6 |  반복 81 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 6 |  반복 101 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 6 |  반복 121 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 6 |  반복 141 / 351 | 시간 8[s] | 손실 0.95
# | 에폭 6 |  반복 161 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 6 |  반복 181 / 351 | 시간 10[s] | 손실 0.92
# | 에폭 6 |  반복 201 / 351 | 시간 11[s] | 손실 0.92
# | 에폭 6 |  반복 221 / 351 | 시간 12[s] | 손실 0.92
# | 에폭 6 |  반복 241 / 351 | 시간 13[s] | 손실 0.91
# | 에폭 6 |  반복 261 / 351 | 시간 15[s] | 손실 0.90
# | 에폭 6 |  반복 281 / 351 | 시간 16[s] | 손실 0.89
# | 에폭 6 |  반복 301 / 351 | 시간 17[s] | 손실 0.89
# | 에폭 6 |  반복 321 / 351 | 시간 18[s] | 손실 0.89
# | 에폭 6 |  반복 341 / 351 | 시간 19[s] | 손실 0.88
# Q 77+85
# T 162
# X 165
# ---
# Q 975+164
# T 1139
# X 1117
# ---
# Q 582+84
# T 666
# X 661
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 848
# ---
# Q 761+292
# T 1053
# X 1027
# ---
# Q 830+597
# T 1427
# X 1400
# ---
# Q 26+838
# T 864
# X 860
# ---
# Q 143+93
# T 236
# X 233
# ---
# 검증 정확도 8.280%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 7 |  반복 41 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 7 |  반복 61 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 7 |  반복 81 / 351 | 시간 4[s] | 손실 0.86
# | 에폭 7 |  반복 101 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 7 |  반복 121 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 7 |  반복 141 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 7 |  반복 161 / 351 | 시간 9[s] | 손실 0.83
# | 에폭 7 |  반복 181 / 351 | 시간 10[s] | 손실 0.82
# | 에폭 7 |  반복 201 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 7 |  반복 221 / 351 | 시간 12[s] | 손실 0.82
# | 에폭 7 |  반복 241 / 351 | 시간 14[s] | 손실 0.81
# | 에폭 7 |  반복 261 / 351 | 시간 15[s] | 손실 0.82
# | 에폭 7 |  반복 281 / 351 | 시간 16[s] | 손실 0.81
# | 에폭 7 |  반복 301 / 351 | 시간 17[s] | 손실 0.79
# | 에폭 7 |  반복 321 / 351 | 시간 18[s] | 손실 0.79
# | 에폭 7 |  반복 341 / 351 | 시간 19[s] | 손실 0.79
# Q 77+85
# T 162
# X 165
# ---
# Q 975+164
# T 1139
# X 1108
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 848
# ---
# Q 761+292
# T 1053
# X 1068
# ---
# Q 830+597
# T 1427
# X 1460
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 240
# ---
# 검증 정확도 9.220%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 8 |  반복 21 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 8 |  반복 41 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 8 |  반복 61 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 8 |  반복 81 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 8 |  반복 101 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 8 |  반복 121 / 351 | 시간 7[s] | 손실 0.76
# | 에폭 8 |  반복 141 / 351 | 시간 8[s] | 손실 0.75
# | 에폭 8 |  반복 161 / 351 | 시간 9[s] | 손실 0.75
# | 에폭 8 |  반복 181 / 351 | 시간 10[s] | 손실 0.75
# | 에폭 8 |  반복 201 / 351 | 시간 12[s] | 손실 0.75
# | 에폭 8 |  반복 221 / 351 | 시간 13[s] | 손실 0.74
# | 에폭 8 |  반복 241 / 351 | 시간 14[s] | 손실 0.72
# | 에폭 8 |  반복 261 / 351 | 시간 15[s] | 손실 0.72
# | 에폭 8 |  반복 281 / 351 | 시간 16[s] | 손실 0.74
# | 에폭 8 |  반복 301 / 351 | 시간 17[s] | 손실 0.74
# | 에폭 8 |  반복 321 / 351 | 시간 19[s] | 손실 0.73
# | 에폭 8 |  반복 341 / 351 | 시간 20[s] | 손실 0.71
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1037
# ---
# Q 830+597
# T 1427
# X 1437
# ---
# Q 26+838
# T 864
# X 869
# ---
# Q 143+93
# T 236
# X 231
# ---
# 검증 정확도 12.480%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 9 |  반복 21 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 9 |  반복 41 / 351 | 시간 2[s] | 손실 0.70
# | 에폭 9 |  반복 61 / 351 | 시간 3[s] | 손실 0.70
# | 에폭 9 |  반복 81 / 351 | 시간 4[s] | 손실 0.70
# | 에폭 9 |  반복 101 / 351 | 시간 5[s] | 손실 0.69
# | 에폭 9 |  반복 121 / 351 | 시간 7[s] | 손실 0.69
# | 에폭 9 |  반복 141 / 351 | 시간 8[s] | 손실 0.68
# | 에폭 9 |  반복 161 / 351 | 시간 9[s] | 손실 0.68
# | 에폭 9 |  반복 181 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 9 |  반복 201 / 351 | 시간 11[s] | 손실 0.68
# | 에폭 9 |  반복 221 / 351 | 시간 12[s] | 손실 0.67
# | 에폭 9 |  반복 241 / 351 | 시간 13[s] | 손실 0.67
# | 에폭 9 |  반복 261 / 351 | 시간 15[s] | 손실 0.67
# | 에폭 9 |  반복 281 / 351 | 시간 16[s] | 손실 0.66
# | 에폭 9 |  반복 301 / 351 | 시간 17[s] | 손실 0.66
# | 에폭 9 |  반복 321 / 351 | 시간 18[s] | 손실 0.66
# | 에폭 9 |  반복 341 / 351 | 시간 19[s] | 손실 0.66
# Q 77+85
# T 162
# X 155
# ---
# Q 975+164
# T 1139
# X 1155
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1405
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 16.120%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 10 |  반복 41 / 351 | 시간 2[s] | 손실 0.65
# | 에폭 10 |  반복 61 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 10 |  반복 81 / 351 | 시간 4[s] | 손실 0.63
# | 에폭 10 |  반복 101 / 351 | 시간 5[s] | 손실 0.63
# | 에폭 10 |  반복 121 / 351 | 시간 7[s] | 손실 0.63
# | 에폭 10 |  반복 141 / 351 | 시간 8[s] | 손실 0.63
# | 에폭 10 |  반복 161 / 351 | 시간 9[s] | 손실 0.63
# | 에폭 10 |  반복 181 / 351 | 시간 10[s] | 손실 0.64
# | 에폭 10 |  반복 201 / 351 | 시간 11[s] | 손실 0.63
# | 에폭 10 |  반복 221 / 351 | 시간 12[s] | 손실 0.65
# | 에폭 10 |  반복 241 / 351 | 시간 14[s] | 손실 0.63
# | 에폭 10 |  반복 261 / 351 | 시간 15[s] | 손실 0.63
# | 에폭 10 |  반복 281 / 351 | 시간 16[s] | 손실 0.61
# | 에폭 10 |  반복 301 / 351 | 시간 17[s] | 손실 0.61
# | 에폭 10 |  반복 321 / 351 | 시간 18[s] | 손실 0.61
# | 에폭 10 |  반복 341 / 351 | 시간 19[s] | 손실 0.61
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1047
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 18.840%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 0.59
# | 에폭 11 |  반복 41 / 351 | 시간 2[s] | 손실 0.58
# | 에폭 11 |  반복 61 / 351 | 시간 3[s] | 손실 0.59
# | 에폭 11 |  반복 81 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 11 |  반복 101 / 351 | 시간 5[s] | 손실 0.58
# | 에폭 11 |  반복 121 / 351 | 시간 7[s] | 손실 0.58
# | 에폭 11 |  반복 141 / 351 | 시간 8[s] | 손실 0.59
# | 에폭 11 |  반복 161 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 11 |  반복 181 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 11 |  반복 201 / 351 | 시간 11[s] | 손실 0.59
# | 에폭 11 |  반복 221 / 351 | 시간 12[s] | 손실 0.58
# | 에폭 11 |  반복 241 / 351 | 시간 14[s] | 손실 0.58
# | 에폭 11 |  반복 261 / 351 | 시간 15[s] | 손실 0.57
# | 에폭 11 |  반복 281 / 351 | 시간 16[s] | 손실 0.57
# | 에폭 11 |  반복 301 / 351 | 시간 17[s] | 손실 0.57
# | 에폭 11 |  반복 321 / 351 | 시간 18[s] | 손실 0.57
# | 에폭 11 |  반복 341 / 351 | 시간 19[s] | 손실 0.57
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1147
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 16.800%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.58
# | 에폭 12 |  반복 21 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.56
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.58
# | 에폭 12 |  반복 81 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 12 |  반복 101 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 12 |  반복 121 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 12 |  반복 141 / 351 | 시간 8[s] | 손실 0.54
# | 에폭 12 |  반복 161 / 351 | 시간 9[s] | 손실 0.55
# | 에폭 12 |  반복 181 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 12 |  반복 201 / 351 | 시간 11[s] | 손실 0.55
# | 에폭 12 |  반복 221 / 351 | 시간 12[s] | 손실 0.54
# | 에폭 12 |  반복 241 / 351 | 시간 14[s] | 손실 0.55
# | 에폭 12 |  반복 261 / 351 | 시간 15[s] | 손실 0.55
# | 에폭 12 |  반복 281 / 351 | 시간 16[s] | 손실 0.55
# | 에폭 12 |  반복 301 / 351 | 시간 17[s] | 손실 0.53
# | 에폭 12 |  반복 321 / 351 | 시간 18[s] | 손실 0.53
# | 에폭 12 |  반복 341 / 351 | 시간 19[s] | 손실 0.54
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1147
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# X 1047
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 21.200%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.53
# | 에폭 13 |  반복 41 / 351 | 시간 2[s] | 손실 0.52
# | 에폭 13 |  반복 61 / 351 | 시간 3[s] | 손실 0.52
# | 에폭 13 |  반복 81 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 13 |  반복 101 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 13 |  반복 121 / 351 | 시간 7[s] | 손실 0.51
# | 에폭 13 |  반복 141 / 351 | 시간 8[s] | 손실 0.51
# | 에폭 13 |  반복 161 / 351 | 시간 9[s] | 손실 0.50
# | 에폭 13 |  반복 181 / 351 | 시간 10[s] | 손실 0.51
# | 에폭 13 |  반복 201 / 351 | 시간 11[s] | 손실 0.51
# | 에폭 13 |  반복 221 / 351 | 시간 12[s] | 손실 0.51
# | 에폭 13 |  반복 241 / 351 | 시간 13[s] | 손실 0.51
# | 에폭 13 |  반복 261 / 351 | 시간 15[s] | 손실 0.51
# | 에폭 13 |  반복 281 / 351 | 시간 16[s] | 손실 0.50
# | 에폭 13 |  반복 301 / 351 | 시간 17[s] | 손실 0.50
# | 에폭 13 |  반복 321 / 351 | 시간 18[s] | 손실 0.49
# | 에폭 13 |  반복 341 / 351 | 시간 19[s] | 손실 0.49
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 233
# ---
# 검증 정확도 26.140%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 14 |  반복 21 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 14 |  반복 41 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 14 |  반복 61 / 351 | 시간 3[s] | 손실 0.49
# | 에폭 14 |  반복 81 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 14 |  반복 101 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 14 |  반복 121 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 14 |  반복 141 / 351 | 시간 8[s] | 손실 0.50
# | 에폭 14 |  반복 161 / 351 | 시간 9[s] | 손실 0.49
# | 에폭 14 |  반복 181 / 351 | 시간 10[s] | 손실 0.49
# | 에폭 14 |  반복 201 / 351 | 시간 11[s] | 손실 0.49
# | 에폭 14 |  반복 221 / 351 | 시간 12[s] | 손실 0.49
# | 에폭 14 |  반복 241 / 351 | 시간 14[s] | 손실 0.48
# | 에폭 14 |  반복 261 / 351 | 시간 15[s] | 손실 0.49
# | 에폭 14 |  반복 281 / 351 | 시간 16[s] | 손실 0.48
# | 에폭 14 |  반복 301 / 351 | 시간 17[s] | 손실 0.48
# | 에폭 14 |  반복 321 / 351 | 시간 18[s] | 손실 0.48
# | 에폭 14 |  반복 341 / 351 | 시간 19[s] | 손실 0.48
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1144
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 855
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 23.560%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 15 |  반복 61 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 15 |  반복 81 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 15 |  반복 101 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 15 |  반복 121 / 351 | 시간 7[s] | 손실 0.46
# | 에폭 15 |  반복 141 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 15 |  반복 161 / 351 | 시간 9[s] | 손실 0.45
# | 에폭 15 |  반복 181 / 351 | 시간 10[s] | 손실 0.45
# | 에폭 15 |  반복 201 / 351 | 시간 11[s] | 손실 0.45
# | 에폭 15 |  반복 221 / 351 | 시간 12[s] | 손실 0.45
# | 에폭 15 |  반복 241 / 351 | 시간 14[s] | 손실 0.46
# | 에폭 15 |  반복 261 / 351 | 시간 15[s] | 손실 0.47
# | 에폭 15 |  반복 281 / 351 | 시간 16[s] | 손실 0.47
# | 에폭 15 |  반복 301 / 351 | 시간 17[s] | 손실 0.46
# | 에폭 15 |  반복 321 / 351 | 시간 18[s] | 손실 0.45
# | 에폭 15 |  반복 341 / 351 | 시간 19[s] | 손실 0.46
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 27.240%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 16 |  반복 41 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 16 |  반복 61 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 16 |  반복 81 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 16 |  반복 101 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 16 |  반복 121 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 16 |  반복 141 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 16 |  반복 161 / 351 | 시간 9[s] | 손실 0.43
# | 에폭 16 |  반복 181 / 351 | 시간 10[s] | 손실 0.43
# | 에폭 16 |  반복 201 / 351 | 시간 11[s] | 손실 0.42
# | 에폭 16 |  반복 221 / 351 | 시간 12[s] | 손실 0.43
# | 에폭 16 |  반복 241 / 351 | 시간 14[s] | 손실 0.44
# | 에폭 16 |  반복 261 / 351 | 시간 15[s] | 손실 0.43
# | 에폭 16 |  반복 281 / 351 | 시간 16[s] | 손실 0.42
# | 에폭 16 |  반복 301 / 351 | 시간 17[s] | 손실 0.43
# | 에폭 16 |  반복 321 / 351 | 시간 18[s] | 손실 0.45
# | 에폭 16 |  반복 341 / 351 | 시간 19[s] | 손실 0.44
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 31.180%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 17 |  반복 41 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 17 |  반복 61 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 17 |  반복 81 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 17 |  반복 101 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 17 |  반복 121 / 351 | 시간 7[s] | 손실 0.42
# | 에폭 17 |  반복 141 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 17 |  반복 161 / 351 | 시간 9[s] | 손실 0.42
# | 에폭 17 |  반복 181 / 351 | 시간 11[s] | 손실 0.42
# | 에폭 17 |  반복 201 / 351 | 시간 12[s] | 손실 0.41
# | 에폭 17 |  반복 221 / 351 | 시간 13[s] | 손실 0.41
# | 에폭 17 |  반복 241 / 351 | 시간 14[s] | 손실 0.42
# | 에폭 17 |  반복 261 / 351 | 시간 15[s] | 손실 0.41
# | 에폭 17 |  반복 281 / 351 | 시간 17[s] | 손실 0.42
# | 에폭 17 |  반복 301 / 351 | 시간 18[s] | 손실 0.41
# | 에폭 17 |  반복 321 / 351 | 시간 19[s] | 손실 0.40
# | 에폭 17 |  반복 341 / 351 | 시간 20[s] | 손실 0.40
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 36.740%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 18 |  반복 21 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 18 |  반복 41 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 18 |  반복 61 / 351 | 시간 3[s] | 손실 0.40
# | 에폭 18 |  반복 81 / 351 | 시간 4[s] | 손실 0.39
# | 에폭 18 |  반복 101 / 351 | 시간 5[s] | 손실 0.40
# | 에폭 18 |  반복 121 / 351 | 시간 7[s] | 손실 0.40
# | 에폭 18 |  반복 141 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 18 |  반복 161 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 18 |  반복 181 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 18 |  반복 201 / 351 | 시간 11[s] | 손실 0.38
# | 에폭 18 |  반복 221 / 351 | 시간 12[s] | 손실 0.39
# | 에폭 18 |  반복 241 / 351 | 시간 14[s] | 손실 0.39
# | 에폭 18 |  반복 261 / 351 | 시간 15[s] | 손실 0.40
# | 에폭 18 |  반복 281 / 351 | 시간 16[s] | 손실 0.39
# | 에폭 18 |  반복 301 / 351 | 시간 17[s] | 손실 0.39
# | 에폭 18 |  반복 321 / 351 | 시간 18[s] | 손실 0.38
# | 에폭 18 |  반복 341 / 351 | 시간 19[s] | 손실 0.39
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 38.240%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 19 |  반복 21 / 351 | 시간 1[s] | 손실 0.38
# | 에폭 19 |  반복 41 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 19 |  반복 61 / 351 | 시간 3[s] | 손실 0.36
# | 에폭 19 |  반복 81 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 19 |  반복 101 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 19 |  반복 121 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 19 |  반복 141 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 19 |  반복 161 / 351 | 시간 9[s] | 손실 0.37
# | 에폭 19 |  반복 181 / 351 | 시간 10[s] | 손실 0.38
# | 에폭 19 |  반복 201 / 351 | 시간 11[s] | 손실 0.36
# | 에폭 19 |  반복 221 / 351 | 시간 12[s] | 손실 0.35
# | 에폭 19 |  반복 241 / 351 | 시간 14[s] | 손실 0.36
# | 에폭 19 |  반복 261 / 351 | 시간 15[s] | 손실 0.36
# | 에폭 19 |  반복 281 / 351 | 시간 16[s] | 손실 0.37
# | 에폭 19 |  반복 301 / 351 | 시간 17[s] | 손실 0.36
# | 에폭 19 |  반복 321 / 351 | 시간 18[s] | 손실 0.35
# | 에폭 19 |  반복 341 / 351 | 시간 19[s] | 손실 0.35
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1147
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 41.880%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 20 |  반복 41 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 20 |  반복 61 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 20 |  반복 81 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 20 |  반복 101 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 20 |  반복 121 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 20 |  반복 141 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 20 |  반복 161 / 351 | 시간 9[s] | 손실 0.33
# | 에폭 20 |  반복 181 / 351 | 시간 10[s] | 손실 0.32
# | 에폭 20 |  반복 201 / 351 | 시간 11[s] | 손실 0.33
# | 에폭 20 |  반복 221 / 351 | 시간 12[s] | 손실 0.34
# | 에폭 20 |  반복 241 / 351 | 시간 13[s] | 손실 0.34
# | 에폭 20 |  반복 261 / 351 | 시간 15[s] | 손실 0.34
# | 에폭 20 |  반복 281 / 351 | 시간 16[s] | 손실 0.34
# | 에폭 20 |  반복 301 / 351 | 시간 17[s] | 손실 0.33
# | 에폭 20 |  반복 321 / 351 | 시간 18[s] | 손실 0.32
# | 에폭 20 |  반복 341 / 351 | 시간 19[s] | 손실 0.32
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1047
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 47.080%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 21 |  반복 41 / 351 | 시간 2[s] | 손실 0.31
# | 에폭 21 |  반복 61 / 351 | 시간 3[s] | 손실 0.30
# | 에폭 21 |  반복 81 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 21 |  반복 101 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 21 |  반복 121 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 21 |  반복 141 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 21 |  반복 161 / 351 | 시간 9[s] | 손실 0.30
# | 에폭 21 |  반복 181 / 351 | 시간 10[s] | 손실 0.29
# | 에폭 21 |  반복 201 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 21 |  반복 221 / 351 | 시간 12[s] | 손실 0.32
# | 에폭 21 |  반복 241 / 351 | 시간 13[s] | 손실 0.32
# | 에폭 21 |  반복 261 / 351 | 시간 15[s] | 손실 0.30
# | 에폭 21 |  반복 281 / 351 | 시간 16[s] | 손실 0.29
# | 에폭 21 |  반복 301 / 351 | 시간 17[s] | 손실 0.29
# | 에폭 21 |  반복 321 / 351 | 시간 18[s] | 손실 0.28
# | 에폭 21 |  반복 341 / 351 | 시간 19[s] | 손실 0.29
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 54.960%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.27
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.27
# | 에폭 22 |  반복 41 / 351 | 시간 2[s] | 손실 0.26
# | 에폭 22 |  반복 61 / 351 | 시간 3[s] | 손실 0.26
# | 에폭 22 |  반복 81 / 351 | 시간 4[s] | 손실 0.26
# | 에폭 22 |  반복 101 / 351 | 시간 5[s] | 손실 0.25
# | 에폭 22 |  반복 121 / 351 | 시간 7[s] | 손실 0.25
# | 에폭 22 |  반복 141 / 351 | 시간 8[s] | 손실 0.26
# | 에폭 22 |  반복 161 / 351 | 시간 9[s] | 손실 0.27
# | 에폭 22 |  반복 181 / 351 | 시간 10[s] | 손실 0.26
# | 에폭 22 |  반복 201 / 351 | 시간 11[s] | 손실 0.25
# | 에폭 22 |  반복 221 / 351 | 시간 12[s] | 손실 0.25
# | 에폭 22 |  반복 241 / 351 | 시간 13[s] | 손실 0.26
# | 에폭 22 |  반복 261 / 351 | 시간 15[s] | 손실 0.25
# | 에폭 22 |  반복 281 / 351 | 시간 16[s] | 손실 0.24
# | 에폭 22 |  반복 301 / 351 | 시간 17[s] | 손실 0.23
# | 에폭 22 |  반복 321 / 351 | 시간 18[s] | 손실 0.23
# | 에폭 22 |  반복 341 / 351 | 시간 19[s] | 손실 0.24
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 62.100%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.21
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.23
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.22
# | 에폭 23 |  반복 61 / 351 | 시간 3[s] | 손실 0.22
# | 에폭 23 |  반복 81 / 351 | 시간 4[s] | 손실 0.24
# | 에폭 23 |  반복 101 / 351 | 시간 5[s] | 손실 0.22
# | 에폭 23 |  반복 121 / 351 | 시간 7[s] | 손실 0.22
# | 에폭 23 |  반복 141 / 351 | 시간 8[s] | 손실 0.21
# | 에폭 23 |  반복 161 / 351 | 시간 9[s] | 손실 0.20
# | 에폭 23 |  반복 181 / 351 | 시간 10[s] | 손실 0.21
# | 에폭 23 |  반복 201 / 351 | 시간 11[s] | 손실 0.21
# | 에폭 23 |  반복 221 / 351 | 시간 13[s] | 손실 0.21
# | 에폭 23 |  반복 241 / 351 | 시간 14[s] | 손실 0.20
# | 에폭 23 |  반복 261 / 351 | 시간 15[s] | 손실 0.21
# | 에폭 23 |  반복 281 / 351 | 시간 16[s] | 손실 0.20
# | 에폭 23 |  반복 301 / 351 | 시간 17[s] | 손실 0.20
# | 에폭 23 |  반복 321 / 351 | 시간 18[s] | 손실 0.20
# | 에폭 23 |  반복 341 / 351 | 시간 19[s] | 손실 0.19
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1436
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 70.660%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.18
# | 에폭 24 |  반복 21 / 351 | 시간 1[s] | 손실 0.18
# | 에폭 24 |  반복 41 / 351 | 시간 2[s] | 손실 0.18
# | 에폭 24 |  반복 61 / 351 | 시간 3[s] | 손실 0.18
# | 에폭 24 |  반복 81 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 24 |  반복 101 / 351 | 시간 5[s] | 손실 0.18
# | 에폭 24 |  반복 121 / 351 | 시간 7[s] | 손실 0.17
# | 에폭 24 |  반복 141 / 351 | 시간 8[s] | 손실 0.17
# | 에폭 24 |  반복 161 / 351 | 시간 9[s] | 손실 0.17
# | 에폭 24 |  반복 181 / 351 | 시간 10[s] | 손실 0.18
# | 에폭 24 |  반복 201 / 351 | 시간 11[s] | 손실 0.18
# | 에폭 24 |  반복 221 / 351 | 시간 13[s] | 손실 0.17
# | 에폭 24 |  반복 241 / 351 | 시간 14[s] | 손실 0.18
# | 에폭 24 |  반복 261 / 351 | 시간 15[s] | 손실 0.18
# | 에폭 24 |  반복 281 / 351 | 시간 16[s] | 손실 0.17
# | 에폭 24 |  반복 301 / 351 | 시간 17[s] | 손실 0.17
# | 에폭 24 |  반복 321 / 351 | 시간 19[s] | 손실 0.16
# | 에폭 24 |  반복 341 / 351 | 시간 20[s] | 손실 0.16
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 76.460%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.14
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.15
# | 에폭 25 |  반복 41 / 351 | 시간 2[s] | 손실 0.15
# | 에폭 25 |  반복 61 / 351 | 시간 3[s] | 손실 0.14
# | 에폭 25 |  반복 81 / 351 | 시간 4[s] | 손실 0.14
# | 에폭 25 |  반복 101 / 351 | 시간 6[s] | 손실 0.14
# | 에폭 25 |  반복 121 / 351 | 시간 7[s] | 손실 0.14
# | 에폭 25 |  반복 141 / 351 | 시간 8[s] | 손실 0.14
# | 에폭 25 |  반복 161 / 351 | 시간 9[s] | 손실 0.13
# | 에폭 25 |  반복 181 / 351 | 시간 10[s] | 손실 0.14
# | 에폭 25 |  반복 201 / 351 | 시간 12[s] | 손실 0.15
# | 에폭 25 |  반복 221 / 351 | 시간 13[s] | 손실 0.14
# | 에폭 25 |  반복 241 / 351 | 시간 14[s] | 손실 0.14
# | 에폭 25 |  반복 261 / 351 | 시간 15[s] | 손실 0.14
# | 에폭 25 |  반복 281 / 351 | 시간 17[s] | 손실 0.14
# | 에폭 25 |  반복 301 / 351 | 시간 18[s] | 손실 0.13
# | 에폭 25 |  반복 321 / 351 | 시간 19[s] | 손실 0.13
# | 에폭 25 |  반복 341 / 351 | 시간 20[s] | 손실 0.12
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 81.580%

# %%
# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\inp032\.conda\envs\yyc\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def step_function(x) :
  if x > 0 :
    return 1
  else :
    return 0

# %% [markdown]
# **넘파이 배열도 지원하도록 수정**

# %%
def step_function(x) :
  y = x > 0
  return y.astype(np.int)

# %%
import numpy as np
x = np.array([-1.0, 1.0, 2.0])
x
# Out:
# array([-1.,  1.,  2.])

# %%
y = x > 0
y = y.astype(np.int)
y
# Out:
# array([0, 1, 1])

# %% [markdown]
# 시그모이드 함수 구현

# %%
def sigmoid(x) :
  return 1 / (1 + np.exp(-x))

print(sigmoid(0.1))
# Out:
# 0.52497918747894

# %%
# coding: utf-8
import os
import sys

sys.path.append("../예제/")  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
                        #weight_decay_lambda=weight_decay_lambda) ## 가중치에 패널티를 주어 오버피팅을 방지한다.

optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.13, test acc:0.1132
# epoch:1, train acc:0.12333333333333334, test acc:0.11
# epoch:2, train acc:0.13666666666666666, test acc:0.1065
# epoch:3, train acc:0.15333333333333332, test acc:0.113
# epoch:4, train acc:0.17333333333333334, test acc:0.1337
# epoch:5, train acc:0.21666666666666667, test acc:0.155
# epoch:6, train acc:0.23666666666666666, test acc:0.1824
# epoch:7, train acc:0.26, test acc:0.2004
# epoch:8, train acc:0.31333333333333335, test acc:0.2234
# epoch:9, train acc:0.35333333333333333, test acc:0.2553
# epoch:10, train acc:0.37, test acc:0.2786
# epoch:11, train acc:0.41, test acc:0.2943
# epoch:12, train acc:0.4266666666666667, test acc:0.3081
# epoch:13, train acc:0.44333333333333336, test acc:0.3224
# epoch:14, train acc:0.47, test acc:0.3431
# epoch:15, train acc:0.49333333333333335, test acc:0.3554
# epoch:16, train acc:0.5233333333333333, test acc:0.3739
# epoch:17, train acc:0.5433333333333333, test acc:0.3769
# epoch:18, train acc:0.5733333333333334, test acc:0.3979
# epoch:19, train acc:0.58, test acc:0.4155
# epoch:20, train acc:0.6, test acc:0.4233
# epoch:21, train acc:0.6266666666666667, test acc:0.4349
# epoch:22, train acc:0.62, test acc:0.4392
# epoch:23, train acc:0.6366666666666667, test acc:0.4657
# epoch:24, train acc:0.6466666666666666, test acc:0.4773
# epoch:25, train acc:0.6566666666666666, test acc:0.4785
# epoch:26, train acc:0.6633333333333333, test acc:0.4888
# epoch:27, train acc:0.6833333333333333, test acc:0.5095
# epoch:28, train acc:0.6733333333333333, test acc:0.5153
# epoch:29, train acc:0.6866666666666666, test acc:0.52
# epoch:30, train acc:0.6666666666666666, test acc:0.5163
# epoch:31, train acc:0.7133333333333334, test acc:0.5551
# epoch:32, train acc:0.7366666666666667, test acc:0.5593
# epoch:33, train acc:0.7466666666666667, test acc:0.5648
# epoch:34, train acc:0.7533333333333333, test acc:0.5714
# epoch:35, train acc:0.7733333333333333, test acc:0.5882
# epoch:36, train acc:0.7666666666666667, test acc:0.5896
# epoch:37, train acc:0.78, test acc:0.6034
# epoch:38, train acc:0.7966666666666666, test acc:0.614
# epoch:39, train acc:0.78, test acc:0.6124
# epoch:40, train acc:0.79, test acc:0.6094
# epoch:41, train acc:0.7866666666666666, test acc:0.6112
# epoch:42, train acc:0.8066666666666666, test acc:0.6252
# epoch:43, train acc:0.8366666666666667, test acc:0.635
# epoch:44, train acc:0.8366666666666667, test acc:0.6427
# epoch:45, train acc:0.8566666666666667, test acc:0.6555
# epoch:46, train acc:0.8466666666666667, test acc:0.6556
# epoch:47, train acc:0.8566666666666667, test acc:0.6596
# epoch:48, train acc:0.86, test acc:0.6591
# epoch:49, train acc:0.87, test acc:0.6576
# epoch:50, train acc:0.8666666666666667, test acc:0.6623
# epoch:51, train acc:0.8733333333333333, test acc:0.6624
# epoch:52, train acc:0.8733333333333333, test acc:0.6686
# epoch:53, train acc:0.88, test acc:0.6707
# epoch:54, train acc:0.8833333333333333, test acc:0.6727
# epoch:55, train acc:0.8833333333333333, test acc:0.6737
# epoch:56, train acc:0.8833333333333333, test acc:0.6813
# epoch:57, train acc:0.89, test acc:0.6798
# epoch:58, train acc:0.89, test acc:0.6777
# epoch:59, train acc:0.9033333333333333, test acc:0.6725
# epoch:60, train acc:0.9066666666666666, test acc:0.6839
# epoch:61, train acc:0.92, test acc:0.6869
# epoch:62, train acc:0.9166666666666666, test acc:0.6901
# epoch:63, train acc:0.92, test acc:0.6894
# epoch:64, train acc:0.9133333333333333, test acc:0.6895
# epoch:65, train acc:0.92, test acc:0.6943
# epoch:66, train acc:0.9333333333333333, test acc:0.6908
# epoch:67, train acc:0.94, test acc:0.6959
# epoch:68, train acc:0.9266666666666666, test acc:0.6758
# epoch:69, train acc:0.9266666666666666, test acc:0.698
# epoch:70, train acc:0.93, test acc:0.7022
# epoch:71, train acc:0.9333333333333333, test acc:0.6899
# epoch:72, train acc:0.95, test acc:0.703
# epoch:73, train acc:0.9433333333333334, test acc:0.7063
# epoch:74, train acc:0.95, test acc:0.704
# epoch:75, train acc:0.95, test acc:0.7057
# epoch:76, train acc:0.96, test acc:0.7058
# epoch:77, train acc:0.9566666666666667, test acc:0.7116
# epoch:78, train acc:0.9533333333333334, test acc:0.7074
# epoch:79, train acc:0.9466666666666667, test acc:0.7122
# epoch:80, train acc:0.9533333333333334, test acc:0.7126
# epoch:81, train acc:0.9666666666666667, test acc:0.7178
# epoch:82, train acc:0.9533333333333334, test acc:0.718
# epoch:83, train acc:0.9566666666666667, test acc:0.7184
# epoch:84, train acc:0.97, test acc:0.7132
# epoch:85, train acc:0.96, test acc:0.719
# epoch:86, train acc:0.9766666666666667, test acc:0.7194
# epoch:87, train acc:0.98, test acc:0.7187
# epoch:88, train acc:0.98, test acc:0.7114
# epoch:89, train acc:0.97, test acc:0.7215
# epoch:90, train acc:0.9733333333333334, test acc:0.7231
# epoch:91, train acc:0.98, test acc:0.7242
# epoch:92, train acc:0.9766666666666667, test acc:0.7225
# epoch:93, train acc:0.9833333333333333, test acc:0.7256
# epoch:94, train acc:0.98, test acc:0.7242
# epoch:95, train acc:0.9833333333333333, test acc:0.7211
# epoch:96, train acc:0.99, test acc:0.7258
# epoch:97, train acc:0.9866666666666667, test acc:0.7254
# epoch:98, train acc:0.9866666666666667, test acc:0.7262
# epoch:99, train acc:0.99, test acc:0.7236
# epoch:100, train acc:0.9866666666666667, test acc:0.7245
# epoch:101, train acc:0.99, test acc:0.7254
# epoch:102, train acc:0.9933333333333333, test acc:0.7306
# epoch:103, train acc:0.9933333333333333, test acc:0.7315
# epoch:104, train acc:0.99, test acc:0.7316
# epoch:105, train acc:0.99, test acc:0.7239
# epoch:106, train acc:0.9933333333333333, test acc:0.7314
# epoch:107, train acc:0.99, test acc:0.7169
# epoch:108, train acc:0.9966666666666667, test acc:0.7337
# epoch:109, train acc:1.0, test acc:0.7278
# epoch:110, train acc:0.9966666666666667, test acc:0.7325
# epoch:111, train acc:1.0, test acc:0.728
# epoch:112, train acc:0.9966666666666667, test acc:0.731
# epoch:113, train acc:0.9933333333333333, test acc:0.7317
# epoch:114, train acc:0.9966666666666667, test acc:0.7335
# epoch:115, train acc:0.9966666666666667, test acc:0.7343
# epoch:116, train acc:0.9966666666666667, test acc:0.7331
# epoch:117, train acc:0.9933333333333333, test acc:0.7339
# epoch:118, train acc:0.9966666666666667, test acc:0.7333
# epoch:119, train acc:1.0, test acc:0.736
# epoch:120, train acc:1.0, test acc:0.7365
# epoch:121, train acc:1.0, test acc:0.7312
# epoch:122, train acc:0.9966666666666667, test acc:0.7357
# epoch:123, train acc:1.0, test acc:0.7351
# epoch:124, train acc:1.0, test acc:0.7376
# epoch:125, train acc:1.0, test acc:0.7358
# epoch:126, train acc:1.0, test acc:0.7394
# epoch:127, train acc:0.9966666666666667, test acc:0.7382
# epoch:128, train acc:1.0, test acc:0.7287
# epoch:129, train acc:1.0, test acc:0.7377
# epoch:130, train acc:1.0, test acc:0.7404
# epoch:131, train acc:1.0, test acc:0.7332
# epoch:132, train acc:1.0, test acc:0.7359
# epoch:133, train acc:1.0, test acc:0.7412
# epoch:134, train acc:1.0, test acc:0.739
# epoch:135, train acc:1.0, test acc:0.7398
# epoch:136, train acc:1.0, test acc:0.7397
# epoch:137, train acc:1.0, test acc:0.7396
# epoch:138, train acc:1.0, test acc:0.7407
# epoch:139, train acc:1.0, test acc:0.7385
# epoch:140, train acc:1.0, test acc:0.739
# epoch:141, train acc:1.0, test acc:0.7417
# epoch:142, train acc:1.0, test acc:0.7408
# epoch:143, train acc:1.0, test acc:0.7374
# epoch:144, train acc:1.0, test acc:0.7399
# epoch:145, train acc:1.0, test acc:0.738
# epoch:146, train acc:1.0, test acc:0.7403
# epoch:147, train acc:1.0, test acc:0.7421
# epoch:148, train acc:1.0, test acc:0.7434
# epoch:149, train acc:1.0, test acc:0.7419
# epoch:150, train acc:1.0, test acc:0.7409
# epoch:151, train acc:1.0, test acc:0.7415
# epoch:152, train acc:1.0, test acc:0.7412
# epoch:153, train acc:1.0, test acc:0.7422
# epoch:154, train acc:1.0, test acc:0.7421
# epoch:155, train acc:1.0, test acc:0.7453
# epoch:156, train acc:1.0, test acc:0.7428
# epoch:157, train acc:1.0, test acc:0.7422
# epoch:158, train acc:1.0, test acc:0.7417
# epoch:159, train acc:1.0, test acc:0.7431
# epoch:160, train acc:1.0, test acc:0.7419
# epoch:161, train acc:1.0, test acc:0.743
# epoch:162, train acc:1.0, test acc:0.7451
# epoch:163, train acc:1.0, test acc:0.7457
# epoch:164, train acc:1.0, test acc:0.7446
# epoch:165, train acc:1.0, test acc:0.7444
# epoch:166, train acc:1.0, test acc:0.7474
# epoch:167, train acc:1.0, test acc:0.744
# epoch:168, train acc:1.0, test acc:0.7447
# epoch:169, train acc:1.0, test acc:0.7429
# epoch:170, train acc:1.0, test acc:0.7424
# epoch:171, train acc:1.0, test acc:0.7448
# epoch:172, train acc:1.0, test acc:0.7459
# epoch:173, train acc:1.0, test acc:0.7451
# epoch:174, train acc:1.0, test acc:0.7442
# epoch:175, train acc:1.0, test acc:0.7448
# epoch:176, train acc:1.0, test acc:0.7458
# epoch:177, train acc:1.0, test acc:0.7441
# epoch:178, train acc:1.0, test acc:0.7445
# epoch:179, train acc:1.0, test acc:0.7462
# epoch:180, train acc:1.0, test acc:0.7476
# epoch:181, train acc:1.0, test acc:0.7458
# epoch:182, train acc:1.0, test acc:0.7486
# epoch:183, train acc:1.0, test acc:0.7465
# epoch:184, train acc:1.0, test acc:0.7456
# epoch:185, train acc:1.0, test acc:0.7465
# epoch:186, train acc:1.0, test acc:0.7473
# epoch:187, train acc:1.0, test acc:0.7479
# epoch:188, train acc:1.0, test acc:0.7473
# epoch:189, train acc:1.0, test acc:0.7466
# epoch:190, train acc:1.0, test acc:0.7462
# epoch:191, train acc:1.0, test acc:0.7476
# epoch:192, train acc:1.0, test acc:0.7479
# epoch:193, train acc:1.0, test acc:0.7465
# epoch:194, train acc:1.0, test acc:0.7487
# epoch:195, train acc:1.0, test acc:0.7481
# epoch:196, train acc:1.0, test acc:0.7488
# epoch:197, train acc:1.0, test acc:0.748
# epoch:198, train acc:1.0, test acc:0.7476
# epoch:199, train acc:1.0, test acc:0.7474
# epoch:200, train acc:1.0, test acc:0.7483
